# %% [markdown]
# <a href="https://colab.research.google.com/github/dewi-ops/capspro/blob/main/capstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff84e65c-eb0a-4ff2-88c2-89b9d0831846" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff84e65c-eb0a-4ff2-88c2-89b9d0831846">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("balanced_ai_human_prompts (1).csv")
print("Ukuran dataset:", df.shape)
df.head()
# Out:
# Ukuran dataset: (2750, 2)
#                                                 text  generated
# 0  Machine learning, a subset of artificial intel...          1
# 1  A decision tree, a prominent machine learning ...          1
# 2  Education, a cornerstone of societal progress,...          1
# 3  Computers, the backbone of modern technology, ...          1
# 4  Chess, a timeless game of strategy and intelle...          1

# %%
print(df.isnull().sum)

df = df.drop_duplicates()
# Out:
# <bound method DataFrame.sum of        text  generated
# 0     False      False
# 1     False      False
# 2     False      False
# 3     False      False
# 4     False      False
# ...     ...        ...
# 2745  False      False
# 2746  False      False
# 2747  False      False
# 2748  False      False
# 2749  False      False
#
# [2750 rows x 2 columns]>

# %%
df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2420 entries, 0 to 2749
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       2420 non-null   object
#  1   generated  2420 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 56.7+ KB
#          generated
# count  2420.000000
# mean      0.431818
# std       0.495432
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Split data
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['generated'], test_size=0.2, random_state=42)

# Vectorize text
vectorizer = TfidfVectorizer(max_features=5000)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Model Logistic Regression
model = LogisticRegression()
model.fit(X_train_vec, y_train)
y_pred = model.predict(X_test_vec)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       295
#            1       0.99      0.99      0.99       189
#
#     accuracy                           0.99       484
#    macro avg       0.99      0.99      0.99       484
# weighted avg       0.99      0.99      0.99       484

# %%
# !pip install replicate
# !pip install langchain_community

# %%
from google.colab import userdata
import os

api_token = userdata.get('api_token')
os.environ['REPLICATE_API_TOKEN'] = api_token

# %%
from langchain_community.llms import replicate

llm = replicate.Replicate(model="ibm-granite/granite-3.3-8b-instruct")

# %%
output = llm.invoke("how to differentiate between AI and human-made writing")

print(output)
# Out:
# 1. Consistency: AI-generated text may lack the subtle variations in tone, style, and vocabulary that human writers naturally employ.
#
# 2. Repetition: AI models might repeat phrases or structures, while human writers avoid repetition to maintain reader interest.
#
# 3. Contextual understanding: Humans can better understand and incorporate complex context, cultural nuances, and emotions into their writing. AI struggles with these aspects, often producing literal or nonsensical responses.
#
# 4. Creativity: Human writing often displays originality, imagination, and unique perspectives, while AI-generated text tends to be more formulaic and less creative.
#
# 5. Fact-checking: Humans can verify information and provide accurate references, whereas AI models may generate incorrect or unsupported facts without realizing it.
#
# 6. Grammar and syntax: Although AI has improved, it may still make occasional grammatical errors or produce awkward phrasings that a human writer would avoid.
#
# ...

# %%
prompt = f"""
What language styles are characteristic of AI and human writing?
"""

output = llm.invoke(prompt)
print("output", output)
# Out:
# output AI and human writing exhibit distinct language styles, each with unique characteristics. Here's a comparison of some key differences:
#
# 1. **Structure and Organization**:
#    - **Human Writing**: Typically follows a more flexible and organic structure, with an emphasis on storytelling, emotion, and personal experiences. Human writers can use various literary devices, such as metaphors, similes, and anecdotes, to engage readers.
#    - **AI Writing**: Tends to be more structured and formulaic, often adhering to specific templates or patterns. AI writing may lack the nuanced storytelling and emotional depth found in human writing, as it primarily relies on data-driven patterns and statistical language models.
#
# 2. **Vocabulary and Style**:
# ...

# %%
prompt = f"""
how close the quality of AI writing is to human quality standards, and identify areas of weakness in both here
"""

print("Prompt:", prompt)

output = llm.invoke(prompt)
print("output:", output)
# Out:
# Prompt:
# how close the quality of AI writing is to human quality standards, and identify areas of weakness in both here
#
# output: AI writing has made significant strides in recent years, often producing content that is coherent, grammatically correct, and contextually relevant. However, it still falls short of human-level writing in several key areas:
#
# 1. **Creativity and Originality**: AI models generate text based on patterns they've learned from vast datasets. They lack the human capacity for original thought, personal experiences, and imaginative leaps. AI might struggle to create truly novel ideas or narratives, often relying on established tropes or clichés.
#
# 2. **Emotional Depth and Nuance**: AI writing can describe emotions and convey basic sentiments but often lacks the depth and subtlety that human writers bring. It may fail to capture complex emotional landscapes, empathize genuinely, or use language to evoke specific feelings in readers.
#
# ...
