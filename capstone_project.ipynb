# %% [markdown]
# <a href="https://colab.research.google.com/github/dewi-ops/capspro/blob/main/capstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5538a0f7-f905-4dac-b13d-23713e1bc7c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5538a0f7-f905-4dac-b13d-23713e1bc7c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("balanced_ai_human_prompts.csv")
print("Ukuran dataset:", df.shape)
df.head()
# Out:
# Ukuran dataset: (2750, 2)
#                                                 text  generated
# 0  Machine learning, a subset of artificial intel...          1
# 1  A decision tree, a prominent machine learning ...          1
# 2  Education, a cornerstone of societal progress,...          1
# 3  Computers, the backbone of modern technology, ...          1
# 4  Chess, a timeless game of strategy and intelle...          1

# %%
print(df.isnull().sum)

df = df.drop_duplicates()
# Out:
# <bound method DataFrame.sum of        text  generated
# 0     False      False
# 1     False      False
# 2     False      False
# 3     False      False
# 4     False      False
# ...     ...        ...
# 2745  False      False
# 2746  False      False
# 2747  False      False
# 2748  False      False
# 2749  False      False
#
# [2750 rows x 2 columns]>

# %%
df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2420 entries, 0 to 2749
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       2420 non-null   object
#  1   generated  2420 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 56.7+ KB
#          generated
# count  2420.000000
# mean      0.431818
# std       0.495432
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Split data
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['generated'], test_size=0.2, random_state=42)

# Vectorize text
vectorizer = TfidfVectorizer(max_features=5000)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Model Logistic Regression
model = LogisticRegression()
model.fit(X_train_vec, y_train)
y_pred = model.predict(X_test_vec)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       295
#            1       0.99      0.99      0.99       189
#
#     accuracy                           0.99       484
#    macro avg       0.99      0.99      0.99       484
# weighted avg       0.99      0.99      0.99       484

# %%
# !pip install replicate
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
from google.colab import userdata
import os

api_token = userdata.get('api_token')
os.environ['REPLICATE_API_TOKEN'] = api_token

# %%
from langchain_community.llms import replicate

llm = replicate.Replicate(model="ibm-granite/granite-3.3-8b-instruct")

# %%
sample_texts = df['text'].sample(5, random_state=42).tolist()
joined_texts = "\n\n".join(sample_texts)

prompt = f"""
From the dataset balanced_ai_human_prompts.csv,
how to differentiate between AI and human-made writing?

Here are some sample texts from the dataset:

{joined_texts}

Please explain the key differences in language style, tone, and structure betwen human and ai.
"""
output = llm.invoke(prompt)
print("Output:\n", "".join(output))
# Out:
# Output:
#  To differentiate between AI and human-written text, one must examine several linguistic features, including style, tone, structure, and the presence of idiosyncrasies. Here’s a step-by-step guide focusing on the provided samples:
#
# 1. **Vocabulary and Phraseology**:
#    - **Human Writing**: Tends to use a wider, more varied vocabulary, including colloquialisms, idioms, and less common words. Sentences are often complex with subclauses and varied sentence structures.
#    - **AI Writing**: May rely on a more limited set of words, repeating phrases or structures, and lacking the nuanced use of idiomatic expressions.
#
# 2. **Grammar and Syntax**:
#    - **Human Writing**: Exhibits natural grammar with occasional deviations (like informal contractions, colloquial usage) that add to the authenticity and readability.
#    - **AI Writing**: Generally adheres strictly to grammatical rules, sometimes resulting in overly formal or stilted language.
#
# ...

# %%
sample_texts = df['text'].sample(5, random_state=42).tolist()
joined_texts = "\n\n".join(sample_texts)

prompt = f"""
From the dataset balanced_ai_human_prompts.csv What language styles are characteristic of AI and human writing?

Here are some sample texts from the dataset:

{joined_texts}

Please explain the detail of characteristic of AI and human writing.
"""
output = llm.invoke(prompt)
print("Output:\n", "".join(output))
# Out:
# Output:
#  To analyze the characteristics of AI and human writing from the given dataset (balanced_ai_human_prompts.csv), we need to examine the provided sample texts for patterns, structures, and stylistic traits typically associated with each. Here’s a step-by-step breakdown:
#
# ### Step 1: Identify Language Complexity
#
# **Human Writing:**
# - **Varied Sentence Structure:** Humans often use complex sentences with subordinate clauses and variations in sentence length to convey nuanced thoughts.
# - **Rich Vocabulary:** Humans tend to employ a wide range of vocabulary, including idioms, colloquialisms, and domain-specific terms.
# - **Contextual Nuance:** Human writing often includes subtle references, cultural allusions, and emotional undertones that are context-dependent.
#
# **AI Writing:**
# - **Simpler Sentence Structure:** AI-generated text typically consists of straightforward sentences, often avoiding complex grammatical structures.
# ...

# %%
sample_texts = df['text'].sample(5, random_state=42).tolist()
joined_texts = "\n\n".join(sample_texts)

prompt = f"""
from the dataset balanced_ai_human_prompts.csv how close the quality of AI writing is to human quality standards, and identify areas of weakness in both here

Here are some sample texts from the dataset:

{joined_texts}

Evaluate them across multiple dimensions such as clarity, coherence, grammar, vocabulary richness, creativity, and consistency of style. Then, identify specific areas of weakness or limitations in both AI-generated and human-generated texts, providing examples where possible.
"""
output = llm.invoke(prompt)
print("Output:\n", "".join(output))
# Out:
# Output:
#  **Analysis of AI and Human Writing Samples**
#
# **Human Writing Samples:**
#
# 1. **Clarity and Coherence:** Human texts demonstrate high clarity and coherence. They present a well-structured argument with a clear introduction, body, and conclusion. The main points about the disadvantages and advantages of limiting car usage are logically connected.
#
#    *Example:* "Limiting car usage could benefit people in many ways... Another advantage... would be more social interactions."
#
# 2. **Grammar:** Human writing is grammatically correct with minimal errors. Sentences are well-constructed, and punctuation is used appropriately.
#
#    *Example:* "When Bogota, Columbia did the Day Without Cars the people would walk where they need to get or rode their bicycle."
#
# 3. **Vocabulary Richness:** Human writers employ a diverse vocabulary, including more sophisticated terms like "greenhouse gas emissions," "car-intensive areas," and "municipal development."
#
# ...

# %%
sample_texts = df['text'].sample(5, random_state=42).tolist()
joined_texts = "\n\n".join(sample_texts)

prompt = f"""
from the dataset balanced_ai_human_prompt.csv, what extent machine learning and generative AI models can help detect human and AI writing

Here are some sample texts from the dataset:

{joined_texts}

Evaluate the models’ performance using metrics such as accuracy, precision, recall, and F1-score.
"""
output = llm.invoke(prompt)
print("Output:\n", "".join(output))
# Out:
# Output:
#  To evaluate the performance of machine learning and generative AI models in distinguishing between human and AI-written text from the 'balanced_ai_human_prompt.csv' dataset, we would need to follow these steps:
#
# 1. **Data Preparation**: Split the dataset into training and testing sets. The training set is used to train the models, while the testing set is used to evaluate their performance.
#
# 2. **Model Training**: Train machine learning and generative AI models on the prepared training data. This could include various models like Naive Bayes, Support Vector Machines (SVM), Recurrent Neural Networks (RNN), Long Short-Term Memory (LSTM), or Transformer-based models like BERT.
#
# 3. **Prediction**: Use the trained models to predict whether each sample in the testing set is written by a human or an AI.
#
# 4. **Evaluation Metrics**: Calculate the following metrics to assess the models' performance:
#
# ...
